# %%
# %matplotlib inline
import Orange
import matplotlib.pyplot as plt

# %%
import olout

# %%
# Out:
# olout.utils.exceptions.ParseError('mess')

# %%
# Branch length radial visualization heuristic
method_names = ['[BRANCH-LENGTH]-unordered_tree_stress', '[BRANCH-LENGTH]-ordered_tree_stress', '[BRANCH-LENGTH]-ordered_tree_fixed_angle_correction_stress', '[BRANCH-LENGTH]-ordered_tree_adj_based_corrections_stress']
method_average_ranks =  [2.5149051490514904, 2.230352303523035, 1.8075880758807588, 3.4471544715447155]


cd = Orange.evaluation.compute_CD(method_average_ranks, 369) 
Orange.evaluation.graph_ranks(method_average_ranks, method_names, cd=cd, width=6, textspace=1.5)
plt.show()

# %%
# Leaf count radial visualization heuristic
method_names = ['[LEAF-COUNT]-unordered_tree_stress', '[LEAF-COUNT]-ordered_tree_stress', '[LEAF-COUNT]-ordered_tree_fixed_angle_correction_stress', '[LEAF-COUNT]-ordered_tree_adj_based_corrections_stress']

method_average_ranks = [2.317073170731707, 2.3441734417344176, 1.981029810298103, 3.3577235772357725]



cd = Orange.evaluation.compute_CD(method_average_ranks, 369) 
Orange.evaluation.graph_ranks(method_average_ranks, method_names, cd=cd, width=6, textspace=1.5)
plt.show()

# %%
# Leaf count and Branch Length radial visualization heuristic
method_names = ['[BRANCH-LENGTH]-unordered_tree_stress', '[BRANCH-LENGTH]-ordered_tree_stress', '[BRANCH-LENGTH]-ordered_tree_fixed_angle_correction_stress', '[BRANCH-LENGTH]-ordered_tree_adj_based_corrections_stress', '[LEAF-COUNT]-unordered_tree_stress', '[LEAF-COUNT]-ordered_tree_stress', '[LEAF-COUNT]-ordered_tree_fixed_angle_correction_stress', '[LEAF-COUNT]-ordered_tree_adj_based_corrections_stress']

method_average_ranks = [2.5528455284552845, 2.2981029810298104, 1.8590785907859078, 3.5149051490514904, 6.233062330623306, 6.300813008130081, 5.926829268292683, 7.314363143631437]


cd = Orange.evaluation.compute_CD(method_average_ranks, 369) 
Orange.evaluation.graph_ranks(method_average_ranks, method_names, cd=cd, width=6, textspace=1.5)
plt.show()
